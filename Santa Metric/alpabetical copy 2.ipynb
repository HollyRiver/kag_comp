# %%
import gc
import os
import time
import math
from math import exp
from collections import Counter
from typing import List, Optional, Union

import numpy as np
import pandas as pd
import transformers
import torch
import heapq
from tqdm import tqdm

import random
import statistics
from collections import Counter
from dataclasses import dataclass
from typing import Any, Callable, List, Optional, Tuple, Union

import torch
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from pprint import pprint

# %%
os.environ['TOKENIZERS_PARALLELISM'] = 'false'

PAD_TOKEN_LABEL_ID = torch.nn.CrossEntropyLoss().ignore_index
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

class HuggingFaceModelLoader:
    def __init__(self, model_path: str, load_in_8bit: bool, device_map: str):
        self.model_path = model_path
        self.load_in_8bit = load_in_8bit
        self.device_map = device_map

    def load_model(self) -> transformers.PreTrainedModel:
        if self.load_in_8bit:
            if DEVICE.type != 'cuda':
                raise ValueError('8-bit quantization requires a CUDA device')

            quantization_config = transformers.BitsAndBytesConfig(
                load_in_4bit=True,
                bnb_4bit_quant_type="fp4",
                bnb_4bit_use_double_quant=False,
                bnb_4bit_compute_dtype=torch.float16,
            )

            model = transformers.AutoModelForCausalLM.from_pretrained(
                self.model_path,
                quantization_config=quantization_config,
                device_map=self.device_map,
                attn_implementation="sdpa"
            )
        else:
            model = transformers.AutoModelForCausalLM.from_pretrained(
                self.model_path,
                torch_dtype=torch.float16 if DEVICE.type == 'cuda' else torch.float32,
                device_map=self.device_map
            )

        model.eval()
        return model


class HuggingFaceTokenizer:
    def __init__(self, model_path: str):
        self.tokenizer = transformers.AutoTokenizer.from_pretrained(model_path, padding_side="right")
        self.bos_token = self.tokenizer.bos_token or self.tokenizer.cls_token
        self.eos_token = self.tokenizer.eos_token or self.tokenizer.sep_token
        if self.bos_token is None:
            self.bos_token = ""
        if self.eos_token is None:
            self.eos_token = ""

    def tokenize(self, texts: List[str]) -> dict:
        processed_texts = []

        for text in texts:
            combined_text = f"{self.bos_token}{text}{self.eos_token}"
            processed_texts.append(combined_text)

        model_inputs = self.tokenizer(
            processed_texts,
            return_tensors='pt',
            add_special_tokens=False,
            padding=True
        )

        if 'token_type_ids' in model_inputs:
            model_inputs.pop('token_type_ids')

        return model_inputs


class PerplexityCalculator:
    def __init__(self, model_loader, tokenizer, exp_mode=False):
        self.model = model_loader.load_model()
        self.model.eval()
        self.tokenizer = tokenizer
        self.exp_mode = exp_mode
        self.loss_fct = torch.nn.CrossEntropyLoss(reduction='none')

    def get_perplexity(
        self,
        input_texts: Union[str, List[str]]
    ) -> Union[float, List[float]]:

        single_input = isinstance(input_texts, str)
        input_texts = [input_texts] if single_input else input_texts

        loss_list = []
        with torch.no_grad():
            input_batch = input_texts
            model_inputs = self.tokenizer.tokenize(input_batch)
            model_inputs = {k: v.to(DEVICE) for k, v in model_inputs.items()}

            output = self.model(**model_inputs, use_cache=False)
            logits = output['logits']

            label = model_inputs['input_ids']
            if hasattr(self.model.config, 'pad_token_id') and self.model.config.pad_token_id is not None:
                label[label == self.model.config.pad_token_id] = PAD_TOKEN_LABEL_ID

            shift_logits = logits[..., :-1, :].contiguous()
            shift_labels = label[..., 1:].contiguous()

            token_loss = self.loss_fct(
                shift_logits.view(-1, shift_logits.size(-1)),
                shift_labels.view(-1)
            ).view(len(logits), -1)

            valid_length = (shift_labels != PAD_TOKEN_LABEL_ID).sum(dim=-1)
            sequence_loss = torch.sum(token_loss, -1) / valid_length
            loss_list.extend(sequence_loss.cpu().tolist())

        if self.exp_mode:
            ppl = [exp(i) for i in loss_list]
        else:
            ppl = loss_list

        return ppl[0] if single_input else ppl

# %%
model_path = "google/gemma-2-9b"
model_loader = HuggingFaceModelLoader(model_path=model_path, load_in_8bit=False, device_map='auto')
tokenizer = HuggingFaceTokenizer(model_path)
scorer = PerplexityCalculator(model_loader, tokenizer, exp_mode=False)
# Out:
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]

# %%
class Configuration:
    """
    A class holding:
      - stopwords (set)
      - semi_free_words (set)
      - config dict:
        {
          'letters': {
            letter_name: {
               'rooms': [ [occupant1, occupant2, ...], ... ]
            },
            ...
          },
          'free_pool': [some stopwords or other items]
        }
    """

    def __init__(self, stopwords=None, semi_free_words=None, initial_config=None):
        self.stopwords = set(stopwords) if stopwords else set()
        self.semi_free_words = set(semi_free_words) if semi_free_words else set()

        if initial_config:
            self.config = initial_config
        else:
            self.config = {
                "letters": {},
                "free_pool": []
            }

    def flatten_encode(self) -> str:
        tokens = []
        tokens.extend(self.config['free_pool'])
        letters_ordered = sorted(self.config['letters'])
        max_room_count = 0
        for lt in letters_ordered:
            max_room_count = max(max_room_count, len(self.config['letters'][lt]['rooms']))

        for room_idx in range(max_room_count):
            for letter in letters_ordered:
                rooms = self.config['letters'][letter]['rooms']
                if room_idx < len(rooms):
                    tokens.extend(rooms[room_idx])

        return ' '.join(tokens)

    def __repr__(self) -> str:
        return self.flatten_encode()

# %%
sample_5_state = {
    'letters': {
        'a': {
            'rooms': [
                ['advent', 'angel'],
                []
                ]
            },
        'b': {
            'rooms': [
                ['bake', 'beard', 'believe', 'bow'],
                []
                ]
            },
        'c': {
            'rooms': [
                ['candle', 'candy', 'card', 'carol', 'cheer', 'cheer', 'chimney', 'chimney', 'chocolate', 'cookie'],
                []
                ]
            },
        'd': {
            'rooms': [
                ['decorations', 'doll', 'dream', 'drive'],
                []
                ]
            },
        'e': {
            'rooms': [
                ['eat', 'eggnog', 'elf'],
                []
                ]
            },
        'f': {
            'rooms': [
                ['family', 'fireplace', 'fireplace', 'fruitcake'],
                []
                ]
            },
        'g': {
            'rooms': [
                ['game', 'gifts', 'gingerbread', 'give', 'greeting', 'grinch'],
                []
                ]
            },
        'h': {
            'rooms': [
                ['hohoho', 'holiday', 'holly', 'hope'],
                []
                ]
            },
        'j': {
            'rooms': [
                [ 'jingle', 'joy', 'jump'],
                []
                ]
            },
        'k': {
            'rooms': [
                ['kaggle'],
                []
                ]
            },
        'l': {
            'rooms': [
                ['laugh'],
                []
                ]
            },
        'm': {
            'rooms': [
                ['magi', 'merry', 'milk', 'mistletoe'],
                []
                ]
            },
        'n': {
            'rooms': [
                ['naughty', 'nice', 'night', 'night', 'nutcracker'],
                []
                ]
            },
        'o': {
            'rooms': [
                ['ornament', 'ornament'],
                []
                ]
            },
        'p': {
            'rooms': [
                ['paper', 'peace', 'peppermint', 'poinsettia', 'polar', 'puzzle'],
                []
                ]
            },
        'r': {
            'rooms': [
                ['reindeer', 'relax'],
                []
                ]
            },
        's': {
            'rooms': [
                ['scrooge', 'season', 'sing', 'sleep', 'sleigh', 'snowglobe', 'star', 'stocking'],
                []
                ]
            },
        't': {
            'rooms': [
                ['toy'],
                []
                ]
            },
        'u': {
            'rooms': [
                ['unwrap'],
                []
                ]
            },
        'v': {
            'rooms': [
                ['visit'],
                []
                ]
            },
        'w': {
            'rooms': [
                ['walk', 'wish', 'wonder', 'workshop', 'workshop', 'wrapping', 'wreath'],
                []
                ]
            },
        'y': {
            'rooms': [
                ['yuletide'],
                []
                ]
            },
        },
    'free_pool': ['the', 'the', 'the', 'of', 'of', 'and', 'to', 'in', 'and', 'is', 'and', 'you', 'that', 'it', 'we', 'with', 'from', 'have', 'not', 'as' ]
    }

stopwords = ['the', 'the', 'the', 'of', 'of', 'and', 'to', 'in', 'and', 'is', 'and', 'you', 'that', 'it', 'we', 'with', 'from', 'have', 'not', 'as' ]

sample5_config = Configuration(stopwords=stopwords, initial_config=sample_5_state)

# %%
class MoveRegistry:
    """
    Holds a collection of moves, each with a weight (probability).
    Each move is a function: move_func(config: Configuration) -> None
    """
    def __init__(self):
        self.moves: List[Tuple[str, Callable[[Configuration], None], float]] = []

    def register_move(self, name: str, func: Callable[[Configuration], None], weight: float):
        self.moves.append((name, func, weight))

    def unregister_move(self, name: str):
        self.moves = [(n, f, w) for (n, f, w) in self.moves if n != name]

    def pick_move(self) -> Callable[[Configuration], None]:
        """Select one move function according to the stored weights."""
        if not self.moves:
            return lambda c: None
        funcs = [m[1] for m in self.moves]
        weights = [m[2] for m in self.moves]
        chosen_func = random.choices(funcs, weights=weights, k=1)[0]
        return chosen_func

# %%
class Moves:
    @staticmethod
    def move_item_between_groups(cfg: Configuration):
        letters = list(cfg.config['letters'])
        if not letters:
            return
        letter_1, letter_2 = random.sample(letters, k=2)
        
        rooms_1 = cfg.config['letters'][letter_1]['rooms']
        rooms_2 = cfg.config['letters'][letter_2]['rooms']
        non_empty_1 = [idx for idx, r in enumerate(rooms_1) if r]
        if not non_empty_1:
            return
            
        src = random.choice(non_empty_1)
        dst = random.choice(list(range(len(rooms_2))))
        
        item_idx = random.randrange(len(rooms_1[src]))
        item = rooms_1[src].pop(item_idx)
        insert_pos = random.randint(0, len(rooms_2[dst]))
        rooms_2[dst].insert(insert_pos, item)
        
    @staticmethod
    def rotate_room_elements(cfg: Configuration):
        letters = list(cfg.config['letters'])
        if not letters:
            return
        letter = random.choice(letters)
        rooms = cfg.config['letters'][letter]['rooms']
        if not rooms:
            return
        r_idx = random.randrange(len(rooms))
        rlist = rooms[r_idx]
        if len(rlist) > 1:
            first_item = rlist.pop(0)
            rlist.append(first_item)

    @staticmethod
    def swap_elements_in_room(cfg: Configuration):
        letters = list(cfg.config['letters'])
        if not letters:
            return
        letter = random.choice(letters)
        rooms = cfg.config['letters'][letter]['rooms']
        swappable = [idx for idx, rlist in enumerate(rooms) if len(rlist) >= 2]
        if not swappable:
            return
        chosen_room_idx = random.choice(swappable)
        rlist = rooms[chosen_room_idx]
        i, j = random.sample(range(len(rlist)), 2)
        rlist[i], rlist[j] = rlist[j], rlist[i]

    @staticmethod
    def move_item_between_rooms(cfg: Configuration):
        letters = list(cfg.config['letters'])
        if not letters:
            return
        letter = random.choice(letters)
        rooms = cfg.config['letters'][letter]['rooms']
        if len(rooms) < 2:
            return
        non_empty = [idx for idx, r in enumerate(rooms) if r]
        if not non_empty:
            return
        src = random.choice(non_empty)
        targets = [i for i in range(len(rooms)) if i != src]
        dst = random.choice(targets)
        item_idx = random.randrange(len(rooms[src]))
        item = rooms[src].pop(item_idx)
        insert_pos = random.randint(0, len(rooms[dst]))
        rooms[dst].insert(insert_pos, item)

    @staticmethod
    def move_item_to_matching_group(cfg: Configuration):
        letters = list(cfg.config['letters'])
        if not letters:
            return
        letter_1 = random.choice(letters)
        rooms_1 = cfg.config['letters'][letter_1]['rooms']
        non_empty_1 = [idx for idx, r in enumerate(rooms_1) if r]
        if not non_empty_1:
            return
        src = random.choice(non_empty_1)
        item_idx = random.randrange(len(rooms_1[src]))
        item = rooms_1[src].pop(item_idx)
        first_letter = item[0].lower()
        if first_letter not in cfg.config['letters']:
            return
        rooms_2 = cfg.config['letters'][first_letter]['rooms']
        dst = random.choice(list(range(len(rooms_2))))
        insert_pos = random.randint(0, len(rooms_2[dst]))
        rooms_2[dst].insert(insert_pos, item)
        

    @staticmethod
    def swap_items_in_free_pool(cfg: Configuration):
        """
        Swap two items at random indices in the free_pool, if the free_pool has >= 2 items.
        """
        pool = cfg.config['free_pool']
        if len(pool) < 2:
            return
        i, j = random.sample(range(len(pool)), 2)
        pool[i], pool[j] = pool[j], pool[i]


    @staticmethod
    def free_to_room(cfg: Configuration):
        if not cfg.config['free_pool']:
            return
        item_idx = random.randrange(len(cfg.config['free_pool']))
        item = cfg.config['free_pool'].pop(item_idx)

        letters = list(cfg.config['letters'])
        if not letters:
            cfg.config['free_pool'].append(item)
            return
        letter = random.choice(letters)
        rooms = cfg.config['letters'][letter]['rooms']
        if not rooms:
            cfg.config['free_pool'].append(item)
            return
        r_idx = random.randrange(len(rooms))
        insert_pos = random.randint(0, len(rooms[r_idx]))
        rooms[r_idx].insert(insert_pos, item)

    @staticmethod
    def room_to_free(cfg: Configuration):
        stopwords = cfg.stopwords
        letters = list(cfg.config['letters'])
        if not letters:
            return
        possible_spots = []
        for letter in letters:
            rooms = cfg.config['letters'][letter]['rooms']
            for i, rlist in enumerate(rooms):
                if any((x in stopwords) for x in rlist):
                    possible_spots.append((letter, i))
        if not possible_spots:
            return
        letter, r_idx = random.choice(possible_spots)
        rlist = cfg.config['letters'][letter]['rooms'][r_idx]
        candidates = [idx for idx, x in enumerate(rlist) if (x in stopwords)]
        if not candidates:
            return
        sw_idx = random.choice(candidates)
        sw = rlist.pop(sw_idx)
        insert_pos = random.randint(0, len(cfg.config['free_pool']))
        cfg.config['free_pool'].insert(insert_pos, sw)

# %%
register = MoveRegistry()
register.register_move('rotate', Moves.rotate_room_elements, 0.2)
register.register_move('swap', Moves.swap_elements_in_room, 0.5)
register.register_move('move', Moves.move_item_between_rooms, 1.0)
register.register_move('group', Moves.move_item_between_groups, 0.5)
# register.register_move('back', Moves.move_item_to_matching_room, 0.2)
#register.register_move('swap2',Moves.swap_items_in_free_pool, 0.2)
#register.register_move('f2r',Moves.free_to_room, 0.2)
#register.register_move('r2f',Moves.room_to_free, 0.2)

# %%
class SimulatedAnnealing:
    def __init__(self, start_temp, end_temp, max_iterations, cost_fn):
        self.start_temp = start_temp
        self.end_temp = end_temp
        self.max_iterations = max_iterations
        self.cost_fn = cost_fn
        self.register = register

    def _generate_neighbor(self, cfg):
        new_cfg = copy.deepcopy(cfg)
        move = self.register.pick_move()
        move(new_cfg)
        return new_cfg

    def _acceptance_probability(self, diff, temperature):
        if diff <= 0:
            return 1.0
        return math.exp(- diff/ temperature)

    def _lower_temperature(self, temperature, iteration):
        t1 = self.end_temp + self.start_temp/(1 + math.log(iteration+1))
        t2 = self.start_temp + (self.end_temp - self.start_temp)*(iteration/self.max_iterations)
        return max(t1, t2)

    def _print_progress(
        self,
        iteration: int,
        best_solutions: List[List[str]],
        best_energies: List[float],
        current_solutions: List[List[str]],
        current_energies: List[float],
        temperature: float,
        start_time: float,
        spend_minute: int
    ) -> int:
        current_time = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())
        elapsed_time = time.time() - start_time

        # Check if 60 seconds have passed since the last update
        if elapsed_time - 60 * spend_minute > 60:
            spend_minute += 1
            progress = iteration / self.max_iterations * 100  # Progress as percentage

            # Print progress in a structured format
            print("===== Simulated Annealing Progress =====")
            print(f"Time: {current_time}")
            print(f"Iteration: {iteration}/{self.max_iterations} ({progress:.2f}%)")
            print(f"Temperature: {temperature:.4f}")
            print(f"Elapsed Time: {elapsed_time:.2f} seconds")

            # Print best solutions and energies
            print("\nBest Solutions:")
            for i, solution in enumerate(best_solutions):
                print(f"  Solution {i+1}: {solution}")
            print("\nBest Energies:")
            print("  " + ", ".join(f"{exp(energy):.4f}" for energy in best_energies))

            # Print current solutions and energies
            print("\nCurrent Solutions:")
            for i, solution in enumerate(current_solutions):
                print(f"  Solution {i+1}: {solution}")
            print("\nCurrent Energies:")
            print("  " + ", ".join(f"{exp(energy):.4f}" for energy in current_energies))

            print("========================================\n")

        return spend_minute

    def solve_batch(self, text_list):
        """
        Perform Simulated Annealing for multiple texts at once.
        """
        solutions = text_list[:]
        current_energies = self.cost_fn(solutions)

        best_solutions = solutions[:]
        best_energies = current_energies[:]

        log_energies = [[] for _ in range(len(text_list))]
        for i in range(len(text_list)):
            log_energies[i].append(current_energies[i])

        temperature = self.start_temp
        start_time = time.time()
        spend_minute = 0

        for iteration in range(self.max_iterations):
            # 1) Generate neighbors
            new_solutions = [self._generate_neighbor(sol) for sol in solutions]

            # 2) Calculate new energies in batch
            new_energies = self.cost_fn(new_solutions)

            # 3) Acceptance and update
            for i in range(len(text_list)):

                diff = new_energies[i] - current_energies[i]
                ap = self._acceptance_probability(diff, temperature)

                if random.random() < ap:
                    solutions[i] = new_solutions[i]
                    current_energies[i] = new_energies[i]

                if current_energies[i] < best_energies[i]:
                    best_solutions[i] = solutions[i]
                    best_energies[i] = current_energies[i]

            # 4) Lower temperature
            temperature = self._lower_temperature(temperature, iteration)

            # 5) Log current energies
            for i in range(len(text_list)):
                log_energies[i].append(current_energies[i])

            # 6) Print progress (extracted into separate method)
            spend_minute = self._print_progress(
                iteration,
                best_solutions,
                best_energies,
                solutions,
                current_energies,
                temperature,
                start_time,
                spend_minute
            )

            # 7) Early stop if temperature is below threshold
            if temperature <= self.end_temp:
                print("Reached the minimum temperature. Exiting.")
                break

        print(f"Execution time: {time.time() - start_time:.4f}s")

        # Convert best solutions back to strings
        return best_solutions, best_energies, log_energies

# %%
def compute_cost(cfg_list: List[Configuration], batch_size: int = 128) -> float:
    all_items = [cfg.flatten_encode() for cfg in cfg_list]
    return scorer.get_perplexity(all_items)

# %%
sa_params = {
    'start_temp': 0.012,             # Initial temperature
    'end_temp': 0.0012,          # Final temperature, decreasing linearly
    'max_iterations': 100000,    # Number of iterations (approximately 4 hours for 100,000 iterations)
    "cost_fn": compute_cost,
}

sa_optimizer = SimulatedAnnealing(**sa_params)

# %%
import copy

states = [copy.deepcopy(sample5_config) for i in range(1)]

# %%
best_solutions, best_energies, log_scores = sa_optimizer.solve_batch(states)
# Out:
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:02:17
# Iteration: 963/100000 (0.96%)
# Temperature: 0.0119
# Elapsed Time: 60.01 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel beard bake believe bow candy carol card candle cheer cheer chimney chimney chocolate cookie doll elf eggnog eat fireplace fireplace fruitcake family give game gingerbread gifts greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi milk merry mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax season sing sleep star stocking toy unwrap visit walk wrapping workshop workshop wreath wonder wish yuletide drive decorations dream scrooge snowglobe sleigh
#
# Current Energies:
#   55.6750
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:03:17
# Iteration: 1929/100000 (1.93%)
# Temperature: 0.0118
# Elapsed Time: 120.03 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake candy carol card cheer cheer candle chimney chimney chocolate cookie doll drive dream eggnog elf fireplace fireplace fruitcake game hohoho gingerbread grinch holiday jingle jump joy kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer scrooge season sleigh sleep snowglobe star stocking yuletide toy unwrap wrapping wonder workshop workshop wish believe beard bow family visit gifts greeting give hope holly wreath decorations eat relax sing walk
#
# Current Energies:
#   54.8118
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:04:17
# Iteration: 2895/100000 (2.90%)
# Temperature: 0.0117
# Elapsed Time: 180.05 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bow dream bake wish beard believe carol card candle cheer cheer chimney chimney chocolate cookie doll decorations eggnog elf family fireplace fireplace fruitcake game give gifts grinch greeting gingerbread hohoho holiday hope jingle jump joy kaggle laugh merry milk mistletoe naughty nice night night nutcracker ornament peace peppermint polar poinsettia puzzle reindeer relax ornament stocking star yuletide season holly magi wonder workshop workshop eat visit walk candy wreath wrapping paper scrooge sing sleep sleigh snowglobe toy drive unwrap
#
# Current Energies:
#   69.0185
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:05:17
# Iteration: 3861/100000 (3.86%)
# Temperature: 0.0116
# Elapsed Time: 240.04 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake dream believe beard magi carol chimney candle cheer chimney chocolate cookie doll eat eggnog fireplace family elf fruitcake greeting hohoho hope jingle jump reindeer joy kaggle laugh merry milk naughty nice night ornament peppermint polar poinsettia fireplace puzzle relax scrooge sing sleep sleigh star stocking yuletide season give toy snowglobe workshop wonder workshop drive walk visit unwrap bow card game gingerbread grinch wish wrapping mistletoe ornament nutcracker paper peace gifts holiday cheer holly candy decorations wreath night
#
# Current Energies:
#   101.2090
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:06:17
# Iteration: 4827/100000 (4.83%)
# Temperature: 0.0115
# Elapsed Time: 300.03 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake dream beard believe give chocolate chimney candle cookie doll elf eat eggnog fruitcake fireplace game grinch holly jump jingle candy reindeer wish laugh milk mistletoe night naughty nice ornament paper nutcracker poinsettia puzzle peppermint polar scrooge chimney sing snowglobe sleep sleigh star stocking yuletide magi gifts card workshop workshop wonder wrapping unwrap visit family bow holiday carol cheer gingerbread greeting hohoho hope joy kaggle season ornament merry fireplace peace relax walk cheer toy wreath decorations drive night
#
# Current Energies:
#   110.7230
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:07:17
# Iteration: 5792/100000 (5.79%)
# Temperature: 0.0114
# Elapsed Time: 360.01 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel beard bow believe candle chocolate chimney cookie doll eat eggnog fireplace gingerbread holly candy jump wish reindeer milk visit naughty nice nutcracker ornament paper peppermint fireplace poinsettia puzzle scrooge sing sleigh stocking star snowglobe toy wreath unwrap workshop workshop wonder walk give wrapping elf bake family carol holiday cheer cheer chimney fruitcake grinch greeting hohoho hope joy kaggle laugh magi merry night ornament peace season jingle card yuletide decorations polar relax sleep mistletoe gifts game night drive dream
#
# Current Energies:
#   108.1581
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:08:17
# Iteration: 6758/100000 (6.76%)
# Temperature: 0.0113
# Elapsed Time: 420.03 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent bake beard carol candle chocolate cookie doll eat eggnog fireplace gingerbread grinch greeting holly candy reindeer wish peace merry mistletoe night ornament paper peppermint poinsettia puzzle scrooge sing sleigh star card chimney game jingle gifts stocking snowglobe wreath workshop workshop unwrap wonder walk angel elf give family wrapping believe holiday hohoho bow cheer cheer chimney fruitcake hope jump joy kaggle laugh magi milk visit naughty nice ornament nutcracker fireplace season night polar relax drive sleep toy yuletide decorations dream
#
# Current Energies:
#   126.9445
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:09:17
# Iteration: 7723/100000 (7.72%)
# Temperature: 0.0112
# Elapsed Time: 480.06 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel carol cheer chocolate doll eggnog fruitcake greeting card holly joy peace reindeer candy wish merry night mistletoe nutcracker ornament paper poinsettia puzzle season jingle game stocking snowglobe star sing sleigh visit drive gingerbread workshop scrooge unwrap workshop walk wonder elf family give wrapping holiday bake believe beard bow candle chimney cookie eat gifts grinch hope jump kaggle laugh magi milk nice night naughty dream fireplace fireplace chimney ornament hohoho wreath peppermint polar relax sleep toy yuletide decorations cheer
#
# Current Energies:
#   118.3253
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:10:17
# Iteration: 8688/100000 (8.69%)
# Temperature: 0.0111
# Elapsed Time: 540.02 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel beard carol doll eggnog fruitcake greeting card kaggle holly candle wish jump joy gingerbread ornament mistletoe milk merry jingle nice nutcracker ornament paper poinsettia puzzle season unwrap star stocking game sleigh snowglobe sing decorations drive polar workshop wonder wreath wrapping elf family gifts holiday bake bow believe scrooge cheer cheer chimney chocolate cookie chimney grinch give hope laugh peace night naughty candy dream night fireplace walk reindeer hohoho magi peppermint fireplace relax visit yuletide toy eat sleep workshop
#
# Current Energies:
#   167.5185
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:11:17
# Iteration: 9654/100000 (9.65%)
# Temperature: 0.0110
# Elapsed Time: 600.05 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bow chocolate doll eggnog fruitcake greeting card kaggle holly jump jingle candle holiday hohoho gingerbread milk merry mistletoe night paper poinsettia puzzle star stocking magi sleigh snowglobe walk sing game toy yuletide season visit wreath wonder workshop workshop fireplace unwrap gifts wrapping elf beard believe chimney cheer cheer scrooge carol cookie bake grinch give hope joy wish nutcracker family laugh ornament naughty nice polar dream ornament peppermint candy night chimney fireplace peace reindeer relax decorations drive eat sleep
#
# Current Energies:
#   136.1916
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:12:17
# Iteration: 10620/100000 (10.62%)
# Temperature: 0.0109
# Elapsed Time: 660.01 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel elf believe chimney chocolate doll eggnog fruitcake greeting holiday kaggle card holly hohoho family gingerbread nutcracker ornament milk mistletoe paper poinsettia puzzle dream stocking magi night star snowglobe walk toy yuletide visit wreath wonder workshop workshop unwrap fireplace wrapping gifts bow beard merry scrooge cheer cheer carol cookie give grinch hope peace joy jump night jingle laugh naughty nice reindeer candle fireplace candy chimney ornament peppermint polar sing game drive bake sleigh relax decorations season wish eat sleep
#
# Current Energies:
#   149.5772
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:13:17
# Iteration: 11587/100000 (11.59%)
# Temperature: 0.0107
# Elapsed Time: 720.03 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel beard believe bow candle chocolate doll elf eggnog fireplace fruitcake holiday hope kaggle jump gingerbread nutcracker ornament ornament paper polar poinsettia peppermint puzzle candy scrooge magi snowglobe sing star sleigh relax yuletide wonder wish workshop workshop unwrap wrapping season family cheer cheer carol cookie visit gifts merry milk peace give greeting grinch hohoho card wreath joy holly mistletoe naughty nice jingle fireplace chimney reindeer dream laugh night game chimney stocking night drive toy bake decorations eat sleep walk
#
# Current Energies:
#   133.5574
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:14:17
# Iteration: 12553/100000 (12.55%)
# Temperature: 0.0106
# Elapsed Time: 780.06 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel beard bow candle believe carol chimney chocolate doll elf eggnog fireplace fruitcake hohoho hope holly kaggle jingle jump joy magi naughty nice ornament polar poinsettia reindeer relax star snowglobe sing sleigh stocking eat walk wonder workshop workshop bake night toy unwrap wrapping yuletide cheer cheer season family cookie gifts grinch greeting give holiday peace milk merry mistletoe gingerbread nutcracker ornament wreath visit laugh scrooge card chimney fireplace dream paper candy peppermint puzzle game night drive decorations sleep wish
#
# Current Energies:
#   104.0146
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:15:17
# Iteration: 13517/100000 (13.52%)
# Temperature: 0.0105
# Elapsed Time: 840.00 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel beard bow chocolate chimney doll elf eggnog fireplace fruitcake give grinch holiday peace hohoho hope holly candle joy magi laugh wreath naughty night nice paper polar ornament poinsettia peppermint puzzle relax star snowglobe sleigh sing stocking walk sleep workshop wonder workshop wish toy unwrap wrapping milk visit cheer cheer carol yuletide season family cookie bake gingerbread greeting jump jingle kaggle merry mistletoe nutcracker ornament scrooge believe card chimney decorations candy reindeer dream fireplace gifts night game drive eat
#
# Current Energies:
#   116.9468
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:16:17
# Iteration: 14483/100000 (14.48%)
# Temperature: 0.0104
# Elapsed Time: 900.05 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel beard bow chimney cookie doll drive elf eggnog fireplace fruitcake give grinch holiday hope peace hohoho kaggle gifts game wish relax believe magi scrooge season laugh naughty nice night peppermint polar reindeer ornament paper poinsettia puzzle stocking star sleigh snowglobe sing sleep walk eat holly toy wrapping unwrap chocolate carol cheer cheer family yuletide bake greeting jingle jump merry milk mistletoe nutcracker joy wreath candle ornament card chimney decorations dream fireplace candy visit night gingerbread workshop wonder workshop
#
# Current Energies:
#   114.6848
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:17:17
# Iteration: 15448/100000 (15.45%)
# Temperature: 0.0103
# Elapsed Time: 960.05 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel beard bow chimney cookie doll eggnog elf fireplace fruitcake grinch holiday hope peace hohoho gingerbread wreath joy magi reindeer scrooge believe dream eat laugh naughty nice night workshop ornament paper poinsettia ornament puzzle game candy peppermint sing star snowglobe stocking drive polar sleep sleigh walk milk toy unwrap carol cheer family holly bake cheer chocolate yuletide wrapping jingle jump give kaggle merry nutcracker mistletoe season relax wish candle card decorations chimney fireplace gifts greeting visit night wonder workshop
#
# Current Energies:
#   126.9445
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:18:17
# Iteration: 16412/100000 (16.41%)
# Temperature: 0.0102
# Elapsed Time: 1020.02 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel beard bow cheer chimney cookie doll eggnog elf fireplace fruitcake grinch gingerbread give holiday hope hohoho cheer merry mistletoe reindeer scrooge believe dream eat laugh naughty nice night workshop paper poinsettia ornament polar puzzle ornament peppermint sing star snowglobe stocking candy game night sleep walk wonder sleigh workshop toy unwrap milk carol chimney chocolate bake family holly yuletide card jingle jump kaggle wish relax wrapping season wreath joy magi candle decorations fireplace gifts greeting visit drive nutcracker peace
#
# Current Energies:
#   124.4892
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:19:17
# Iteration: 17377/100000 (17.38%)
# Temperature: 0.0101
# Elapsed Time: 1080.01 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel beard bow cheer chimney chocolate cookie doll eggnog elf fireplace fruitcake grinch gingerbread give holiday hope hohoho kaggle reindeer scrooge believe dream eat laugh naughty nice night paper polar ornament poinsettia puzzle wrapping peppermint game drive sing nutcracker night sleep sleigh workshop walk wonder toy unwrap cheer yuletide family holly greeting card bake jingle jump relax merry season milk mistletoe ornament carol joy magi candle candy decorations workshop fireplace chimney stocking wish star visit snowglobe wreath gifts peace
#
# Current Energies:
#   118.3253
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:20:17
# Iteration: 18342/100000 (18.34%)
# Temperature: 0.0100
# Elapsed Time: 1140.04 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel beard bow cheer chocolate chimney cookie elf fireplace fruitcake grinch gingerbread give holiday hope jump kaggle merry mistletoe milk reindeer scrooge believe dream laugh naughty nice night ornament polar puzzle paper poinsettia visit drive sleigh sleep walk workshop toy unwrap eat cheer nutcracker relax peppermint candle family sing bake greeting card wrapping jingle doll hohoho wish ornament season carol workshop wonder magi night holly candy joy fireplace chimney yuletide eggnog snowglobe star stocking decorations game gifts wreath peace
#
# Current Energies:
#   134.0801
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:21:17
# Iteration: 19307/100000 (19.31%)
# Temperature: 0.0099
# Elapsed Time: 1200.02 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel beard cheer cookie doll chimney reindeer elf fruitcake grinch give hope holiday jump kaggle gingerbread milk fireplace wonder workshop believe dream laugh magi naughty nice polar ornament puzzle paper poinsettia chimney drive ornament carol sleep eat candy walk visit relax toy unwrap candle nutcracker peppermint peace chocolate sing family hohoho merry yuletide greeting card wreath wrapping gifts decorations bow wish season fireplace mistletoe game night scrooge joy holly cheer snowglobe eggnog stocking star night jingle bake sleigh workshop
#
# Current Energies:
#   165.5668
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:22:17
# Iteration: 20273/100000 (20.27%)
# Temperature: 0.0098
# Elapsed Time: 1260.05 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel beard believe candle cheer chocolate cookie doll stocking chimney drive eggnog fireplace elf game fruitcake grinch give holiday hope jump kaggle wish workshop wonder joy laugh magi naughty nice polar ornament paper poinsettia puzzle reindeer sing bake eat sleep walk relax unwrap toy nutcracker wrapping peppermint peace family merry yuletide greeting card wreath bow candy milk hohoho decorations night scrooge dream holly season gifts chimney night star snowglobe mistletoe ornament fireplace gingerbread cheer carol jingle visit workshop sleigh
#
# Current Energies:
#   123.0388
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:23:17
# Iteration: 21238/100000 (21.24%)
# Temperature: 0.0097
# Elapsed Time: 1320.03 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel beard walk candle cheer believe chocolate chimney cookie doll drive eggnog fireplace fruitcake gifts grinch holiday hope jump kaggle candy wish workshop wonder season joy laugh magi elf mistletoe sleigh naughty nice night nutcracker ornament polar paper poinsettia puzzle reindeer relax star night snowglobe sleep peppermint toy family cheer peace gingerbread greeting card merry game give bow wrapping decorations dream holly hohoho wreath unwrap eat stocking visit bake sing yuletide scrooge jingle ornament fireplace chimney carol milk workshop
#
# Current Energies:
#   118.7884
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:24:17
# Iteration: 22204/100000 (22.20%)
# Temperature: 0.0096
# Elapsed Time: 1380.06 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel star walk candle chocolate chimney cookie doll drive eggnog fireplace fruitcake gifts give grinch holiday hope jump kaggle wonder joy laugh magi mistletoe naughty nice night nutcracker ornament paper poinsettia puzzle polar reindeer relax merry carol jingle eat sleep beard bake game peace cheer elf family night milk cheer greeting card gingerbread season believe candy bow peppermint decorations holly hohoho yuletide dream ornament toy scrooge sing sleigh wish unwrap snowglobe visit workshop wrapping chimney fireplace wreath workshop stocking
#
# Current Energies:
#   127.4413
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:25:17
# Iteration: 23169/100000 (23.17%)
# Temperature: 0.0095
# Elapsed Time: 1440.04 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bow chimney cheer chocolate cookie doll game drive eggnog fireplace fruitcake gifts grinch holiday hope jump kaggle give laugh magi merry mistletoe naughty nice night nutcracker ornament paper poinsettia puzzle reindeer relax visit season sing eat sleep walk peace bake beard elf family star night milk cheer greeting card candle candy peppermint joy holly hohoho decorations dream jingle ornament toy workshop workshop polar believe scrooge sleigh unwrap wrapping wonder wreath fireplace chimney carol gingerbread snowglobe stocking wish yuletide
#
# Current Energies:
#   95.0770
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:26:17
# Iteration: 24134/100000 (24.13%)
# Temperature: 0.0094
# Elapsed Time: 1500.01 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bow cheer chocolate chimney cookie drive eggnog fireplace fruitcake give gifts grinch holiday hope jump kaggle laugh magi merry mistletoe naughty nice night nutcracker ornament paper poinsettia puzzle reindeer relax visit season sing sleep eat walk bake beard game star family night milk cheer greeting card candle candy peppermint holly hohoho joy decorations dream doll elf jingle workshop ornament toy workshop polar believe sleigh scrooge stocking unwrap wrapping wish wonder yuletide peace chimney fireplace wreath carol snowglobe gingerbread
#
# Current Energies:
#   88.2760
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:27:17
# Iteration: 25100/100000 (25.10%)
# Temperature: 0.0093
# Elapsed Time: 1560.03 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard cheer chocolate chimney drive eggnog fireplace fruitcake gifts give grinch holiday hope kaggle jump laugh magi naughty nice night nutcracker polar ornament paper poinsettia puzzle reindeer relax visit season sing sleep eat toy walk believe family game night milk cheer greeting card star wrapping candle candy gingerbread peppermint holly hohoho cookie decorations doll dream joy merry mistletoe elf workshop sleigh scrooge ornament stocking snowglobe workshop unwrap wonder wish peace yuletide bow wreath chimney fireplace carol jingle
#
# Current Energies:
#   95.8227
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:28:17
# Iteration: 26066/100000 (26.07%)
# Temperature: 0.0092
# Elapsed Time: 1620.04 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard cheer chocolate chimney drive eggnog fireplace fruitcake gifts give grinch holiday hope kaggle jump laugh magi naughty nice night nutcracker polar ornament paper poinsettia puzzle reindeer relax season sing carol eat sleep unwrap walk family game night greeting card star wish workshop candle wrapping candy sleigh holly hohoho cookie decorations doll dream joy merry mistletoe milk elf ornament peppermint stocking scrooge snowglobe toy workshop visit wonder peace wreath fireplace chimney yuletide jingle bow believe cheer gingerbread
#
# Current Energies:
#   90.0171
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:29:17
# Iteration: 27032/100000 (27.03%)
# Temperature: 0.0091
# Elapsed Time: 1680.03 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard cheer chocolate chimney drive eggnog fireplace fruitcake gifts give grinch holiday hope jump kaggle laugh milk naughty nice night nutcracker ornament paper poinsettia puzzle reindeer relax season sing eat sleep star unwrap walk family game night greeting card wish workshop wrapping candle believe candy stocking sleigh elf gingerbread holly hohoho cookie decorations doll dream joy magi merry mistletoe ornament peppermint polar scrooge toy workshop visit wonder wreath snowglobe peace carol jingle bow chimney fireplace yuletide cheer
#
# Current Energies:
#   79.7508
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:30:17
# Iteration: 27998/100000 (28.00%)
# Temperature: 0.0090
# Elapsed Time: 1740.01 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard cheer chocolate candy drive eggnog fireplace fruitcake give gifts grinch holiday hope jump kaggle laugh magi milk naughty nice night nutcracker ornament paper puzzle poinsettia reindeer relax season sing sleep star unwrap sleigh walk family game night greeting toy workshop wish card wrapping believe candle chimney elf eat gingerbread holly hohoho cookie decorations dream joy merry mistletoe ornament peppermint polar scrooge stocking visit workshop wonder peace wreath snowglobe jingle doll bow carol fireplace chimney yuletide cheer
#
# Current Energies:
#   89.3166
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:31:17
# Iteration: 28963/100000 (28.96%)
# Temperature: 0.0089
# Elapsed Time: 1800.00 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel walk bake beard cheer chocolate candy drive eggnog fireplace fruitcake give gifts grinch holiday hope kaggle jump laugh milk naughty nice night nutcracker ornament paper puzzle reindeer relax season sing sleep snowglobe toy sleigh unwrap family game fireplace greeting night wish workshop wrapping candle card believe chimney elf eat gingerbread holly hohoho cookie decorations dream joy magi merry mistletoe ornament peppermint polar poinsettia scrooge stocking visit workshop wonder wreath peace bow cheer yuletide carol chimney doll jingle star
#
# Current Energies:
#   80.0629
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 14:32:17
# Iteration: 29929/100000 (29.93%)
# Temperature: 0.0088
# Elapsed Time: 1860.04 seconds
#
# Best Solutions:
# ...
#
# Current Energies:
#   40.1012
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 15:35:17
# Iteration: 90763/100000 (90.76%)
# Temperature: 0.0022
# Elapsed Time: 5640.05 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel beard bow chimney doll drive eat family give gifts grinch holiday hohoho hope joy laugh magi merry naughty nice night ornament peace polar relax reindeer season sing sleep star stocking toy unwrap walk wish workshop wreath yuletide bake believe cheer chocolate cookie decorations dream elf game night eggnog fireplace fruitcake gingerbread greeting card holly jingle jump kaggle milk mistletoe nutcracker ornament peppermint poinsettia puzzle scrooge snowglobe wrapping paper carol candy candle cheer chimney fireplace sleigh visit wonder workshop
#
# Current Energies:
#   40.2582
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 15:36:17
# Iteration: 91734/100000 (91.73%)
# Temperature: 0.0022
# Elapsed Time: 5700.02 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel beard bow chimney doll drive eat family gifts give grinch holiday hohoho hope joy laugh magi merry naughty nice night ornament peace polar reindeer relax season sing sleep star stocking toy unwrap walk wish workshop yuletide bake believe cheer chocolate cookie decorations dream elf game night eggnog fireplace fruitcake gingerbread greeting card holly jingle jump kaggle milk mistletoe nutcracker ornament peppermint poinsettia puzzle scrooge snowglobe wrapping paper carol candy candle cheer chimney fireplace sleigh visit wonder workshop wreath
#
# Current Energies:
#   39.4025
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 15:37:17
# Iteration: 92695/100000 (92.70%)
# Temperature: 0.0022
# Elapsed Time: 5760.03 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel beard bow chimney doll drive eat family gifts give grinch holiday hohoho hope joy laugh magi merry naughty nice night ornament peace polar reindeer relax season sing sleep star stocking toy unwrap walk wish yuletide bake believe cheer chocolate cookie decorations dream elf game night eggnog fireplace fruitcake gingerbread greeting card holly jingle jump kaggle milk mistletoe nutcracker ornament peppermint poinsettia puzzle scrooge snowglobe wrapping paper carol candy candle cheer chimney fireplace sleigh visit wonder workshop workshop wreath
#
# Current Energies:
#   39.4795
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 15:38:17
# Iteration: 93653/100000 (93.65%)
# Temperature: 0.0022
# Elapsed Time: 5820.00 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel beard bow candy chimney doll drive eat family gifts give grinch holiday hohoho hope joy laugh magi merry naughty nice night ornament peace polar reindeer relax season sing sleep star toy unwrap walk wish wonder workshop yuletide bake believe cheer chocolate cookie decorations dream elf game night eggnog fireplace fruitcake gingerbread greeting card holly jingle jump kaggle milk mistletoe nutcracker ornament peppermint poinsettia puzzle scrooge snowglobe wrapping paper carol candle cheer chimney sleigh fireplace stocking visit workshop wreath
#
# Current Energies:
#   39.6340
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 15:39:17
# Iteration: 94615/100000 (94.62%)
# Temperature: 0.0022
# Elapsed Time: 5880.01 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel beard bow chimney doll drive eat family gifts give grinch holiday hohoho hope joy laugh magi merry naughty nice night ornament peace polar reindeer relax season sing sleep star toy unwrap walk wish wonder workshop yuletide bake believe cheer chocolate cookie decorations dream elf game night eggnog fireplace fruitcake gingerbread greeting card holly jingle jump kaggle milk mistletoe nutcracker ornament peppermint poinsettia puzzle scrooge snowglobe wrapping paper carol candy candle cheer chimney fireplace sleigh stocking visit workshop wreath
#
# Current Energies:
#   39.4795
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 15:40:17
# Iteration: 95579/100000 (95.58%)
# Temperature: 0.0022
# Elapsed Time: 5940.04 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel beard bow candy chimney doll drive eat family gifts give grinch holiday hohoho hope joy laugh magi merry naughty nice night ornament peace polar reindeer relax season sing sleep star sleigh toy unwrap walk wish wonder workshop yuletide bake believe cheer chocolate cookie decorations dream elf game night eggnog fireplace fruitcake gingerbread greeting card holly jingle jump kaggle milk mistletoe nutcracker ornament peppermint poinsettia puzzle scrooge snowglobe wrapping paper carol candle cheer chimney fireplace stocking visit workshop wreath
#
# Current Energies:
#   39.3256
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 15:41:17
# Iteration: 96541/100000 (96.54%)
# Temperature: 0.0022
# Elapsed Time: 6000.02 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel beard bow candy chimney doll drive eat family gifts give grinch holiday hohoho hope joy laugh magi merry naughty nice night ornament peace polar reindeer relax season sing sleep star toy unwrap walk wish workshop yuletide bake believe cheer chocolate cookie decorations dream elf game night eggnog fireplace fruitcake gingerbread greeting card holly jingle jump kaggle milk mistletoe nutcracker ornament peppermint poinsettia puzzle scrooge snowglobe wrapping paper carol candle cheer chimney fireplace sleigh stocking visit wonder workshop wreath
#
# Current Energies:
#   39.1723
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 15:42:17
# Iteration: 97503/100000 (97.50%)
# Temperature: 0.0022
# Elapsed Time: 6060.02 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel beard bow candy chimney doll drive eat family gifts give grinch holiday hohoho hope joy laugh magi merry naughty nice night ornament peace polar reindeer relax season sing sleep star sleigh toy unwrap walk wish workshop yuletide bake believe cheer chocolate cookie decorations dream elf game night eggnog fireplace fruitcake gingerbread greeting card holly jingle jump kaggle milk mistletoe nutcracker ornament peppermint poinsettia puzzle scrooge snowglobe wrapping paper carol candle cheer chimney fireplace stocking visit wonder workshop wreath
#
# Current Energies:
#   39.3256
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 15:43:17
# Iteration: 98464/100000 (98.46%)
# Temperature: 0.0022
# Elapsed Time: 6120.06 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel beard bow candy chimney doll drive eat family give gifts grinch holiday hohoho hope joy laugh magi merry naughty nice night ornament peace polar reindeer relax season sing sleep star sleigh toy unwrap walk wish wonder workshop yuletide bake believe cheer chocolate cookie decorations dream elf game night eggnog fireplace fruitcake gingerbread greeting card holly jingle jump kaggle milk mistletoe nutcracker ornament peppermint poinsettia puzzle scrooge snowglobe wrapping paper carol candle cheer chimney fireplace stocking visit workshop wreath
#
# Current Energies:
#   39.4795
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-28 15:44:17
# Iteration: 99424/100000 (99.42%)
# Temperature: 0.0022
# Elapsed Time: 6180.04 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel bake beard believe bow candle candy card carol cheer cheer chimney chimney chocolate cookie decorations doll dream drive eat eggnog elf family fireplace fireplace fruitcake game gifts gingerbread give greeting grinch hohoho holiday holly hope jingle joy jump kaggle laugh magi merry milk mistletoe naughty nice night night nutcracker ornament ornament paper peace peppermint poinsettia polar puzzle reindeer relax scrooge season sing sleep sleigh snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wrapping wreath yuletide
#
# Best Energies:
#   38.1157
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent angel beard bow candy chimney doll drive eat family give gifts grinch holiday hohoho hope joy laugh magi merry naughty nice night ornament peace polar reindeer relax season sing sleep star toy sleigh unwrap walk wish wonder workshop yuletide bake believe cheer chocolate cookie decorations dream elf game night eggnog fireplace fruitcake gingerbread greeting card holly jingle jump kaggle milk mistletoe nutcracker ornament peppermint poinsettia puzzle scrooge snowglobe wrapping paper carol candle cheer chimney fireplace stocking visit workshop wreath
#
# Current Energies:
#   39.7891
# ========================================
#
# Execution time: 6215.8413s

# %%
def create_new_config_from_tokens(tokens, original_config) :
    # 원본 config의 구조를 복사
    new_config = copy.deepcopy(original_config.config)
    
    # free_pool은 stopwords로 분류
    new_config['free_pool'] = [token for token in tokens if token in original_config.stopwords]
    
    # 나머지 토큰들은 letters로 분류
    for token in tokens:
        if token not in original_config.stopwords:
            first_letter = token[0].lower()
            if first_letter not in new_config['letters']:
                new_config['letters'][first_letter] = {'rooms': [[]]}  # 기본 room 생성
            # 첫 번째 room에 토큰 추가
            new_config['letters'][first_letter]['rooms'][0].append(token)
    
    # 새로운 Configuration 객체 생성
    return Configuration(stopwords=original_config.stopwords, initial_config=new_config)

# %%
sample = " ".join(['the', 'grinch', 'eat', 'not', 'you', 'scrooge', 'and', 'hohoho', 'yuletide',
  'greeting', 'have', 'merry', 'unwrap', 'give', 'as', 'we', 'the', 'of', 'to',
  'from', 'toy', 'doll', 'ornament', 'snowglobe', 'card', 'game', 'puzzle',
  'advent', 'candle', 'wreath', 'cookie', 'bake', 'fruitcake', 'gingerbread',
  'candy', 'peppermint', 'chocolate', 'milk', 'and', 'eggnog', 'sleigh', 'drive',
  'reindeer', 'jump', 'polar', 'kaggle', 'beard', 'elf', 'workshop', 'workshop',
  'naughty', 'nice', 'wrapping', 'paper', 'bow', 'ornament', 'nutcracker',
  'poinsettia', 'holly', 'mistletoe', 'jingle', 'relax', 'family', 'laugh',
  'joy', 'peace', 'sleep', 'dream', 'wish', 'hope', 'believe', 'wonder', 'magi',
  'visit', 'with', 'gifts', 'in', 'stocking', 'chimney', 'fireplace',
  'fireplace', 'chimney', 'star', 'angel', 'night', 'night', 'walk', 'carol',
  'sing', 'holiday', 'decorations', 'that', 'it', 'is', 'the', 'season', 'of',
  'cheer', 'and', 'cheer'])

# %%
# 재배치된 토큰들로 새로운 config 생성
new_config = create_new_config_from_tokens(sample, sample5_config)
